# %%
# imports
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# load each file into a dict of dataframes
data = {}
file_names = os.listdir('data/afl')
for file_name in file_names:
    with open('data/afl/' + file_name) as f:
        data[file_name[:-4]] = pd.read_csv(f)
        # rename the ID column to Player ID
        data[file_name[:-4]].rename(columns={'ID': 'Player ID'}, inplace=True)
        # snake case the column names
        data[file_name[:-4]].columns = data[file_name[:-4]].columns.str.lower().str.replace(' ', '_')
        # add year column to each dataframe
        data[file_name[:-4]]['year'] = file_name[0:4]

# %%
data['2010_stats'].tail()
# Out:
#                   player  player_id team opponent round  kicks  marks  \
# 8179   Steele Sidebottom      11751   CW       SK    GF     16      6
# 8180           Dane Swan       1460   CW       SK    GF     18      6
# 8181         Dale Thomas       4152   CW       SK    GF     20      8
# 8182         Alan Toovey      11553   CW       SK    GF      8      7
# 8183  Sharrod Wellingham      11654   CW       SK    GF     11      3
#
#       hand_balls  disp  goals  behinds  hit_outs  tackles  rebounds  \
# 8179           9    25      2        0         0        4         3
# 8180           8    26      1        0         0       11         0
# 8181           7    27      1        2         1        1         2
# 8182           7    15      0        0         0        9         0
# 8183           9    20      2        1         0        8         0
#
#       inside_50  clearances  clangers  frees_for  frees_against  brownlow  \
# 8179          3           2         0          1              0         0
# 8180          4           7         1          3              0         0
# 8181          3           4         3          1              0         0
# 8182          1           1         4          0              0         0
# 8183          3           7         1          1              0         0
#
#       contested_possessions  uncontested_possessions  contested_marks  \
# 8179                      9                       16                0
# 8180                      9                       16                0
# 8181                     11                       17                0
# 8182                      4                       11                0
# 8183                     11                        9                0
#
#       marks_inside_50  one_percenters  bounces  goal_assists  %_time_played  \
# 8179                2               2        0             1             80
# 8180                0               2        1             0             90
# 8181                1               3        2             0             80
# 8182                1               1        0             0            100
# 8183                1               2        0             1             70
#
#       year
# 8179  2010
# 8180  2010
# 8181  2010
# 8182  2010
# 8183  2010

# %%
# get distinct Teams from data['2023_stats]
teams = data['2023_stats']['team'].unique()
teams
# Out:
# array(['RI', 'CA', 'CW', 'GE', 'NM', 'WC', 'PA', 'BL', 'SY', 'GC', 'ME',
#        'WB', 'AD', 'GW', 'HW', 'ES', 'SK', 'FR'], dtype=object)

# %%
# Our composite key will be player, year and round.
# In 2010 there were 2 grand finals, so we need to change the second `round` to "GF2", but keep the first as "GF"
# Step 1: Find all the rounds that are GF in 2010
data['2010_stats'][data['2010_stats']['round'].str.contains('GF')]

# Step 2: Edit the round column to have GF and GF2
mask = data['2010_stats']['round'].str.contains('GF')
data['2010_stats'].loc[mask & (data['2010_stats'].index < 8140), 'round'] = 'GF'
data['2010_stats'].loc[mask & (data['2010_stats'].index >= 8140), 'round'] = 'GF2'

# %%
data['2010_stats'][data['2010_stats']['round'].str.contains('GF')]
# Out:
#                   player  player_id team opponent round  kicks  marks  \
# 8096        Steven Baker        967   SK       CW    GF      4      2
# 8097         Jason Blake        974   SK       CW    GF      5      3
# 8098      Nick Dal Santo       1132   SK       CW    GF     10      1
# 8099          Zac Dawson       4141   SK       CW    GF      3      4
# 8100       Sean Dempster       4073   SK       CW    GF      9      5
# 8101         Robert Eddy      11681   SK       CW    GF      3      2
# 8102          Sam Fisher       3975   SK       CW    GF     22      8
# 8103    Michael Gardiner       1056   SK       CW    GF      2      0
# 8104         Sam Gilbert       4178   SK       CW    GF      9      4
# 8105     Brendon Goddard       1443   SK       CW    GF     18      5
# 8106          Jason Gram       1462   SK       CW    GF      8      1
# 8107         James Gwilt       4143   SK       CW    GF     11      5
# 8108         Lenny Hayes        966   SK       CW    GF     18      5
# 8109       Clinton Jones      11554   SK       CW    GF      9      2
# 8110   Justin Koschitzke        977   SK       CW    GF      8      4
# 8111    Andrew McQualter       4104   SK       CW    GF      5      3
# 8112       Stephen Milne        978   SK       CW    GF      7      2
# 8113      Leigh Montagna       1137   SK       CW    GF     11      1
# 8114         Brett Peake       4122   SK       CW    GF      6      2
# 8115          Farren Ray       3974   SK       CW    GF      2      2
# 8116       Nick Riewoldt        981   SK       CW    GF     13      8
# 8117      Adam Schneider       1432   SK       CW    GF     10      5
# 8118           Luke Ball       1430   CW       SK    GF      5      1
# 8119         Dayne Beams      11728   CW       SK    GF      3      2
# 8120        Jarryd Blair      11855   CW       SK    GF      5      1
# 8121         Leigh Brown        539   CW       SK    GF      8      4
# 8122        Nathan Brown      11627   CW       SK    GF      4      2
# 8123        Travis Cloke       4086   CW       SK    GF     11      5
# 8124          Leon Davis        284   CW       SK    GF      4      0
# 8125         Chris Dawes      11696   CW       SK    GF      7      5
# 8126          Alan Didak        301   CW       SK    GF      8      2
# 8127         Ben Johnson        286   CW       SK    GF     11      1
# 8128        Darren Jolly        753   CW       SK    GF      8      4
# 8129    Heritier Lumumba       4134   CW       SK    GF      9      4
# 8130      Brent Macaffer      11743   CW       SK    GF     10      5
# 8131        Nick Maxwell       3980   CW       SK    GF     10      5
# 8132    Scott Pendlebury       4182   CW       SK    GF      5      1
# 8133            Ben Reid      11589   CW       SK    GF      8      4
# 8134          Heath Shaw       4132   CW       SK    GF     21      5
# 8135   Steele Sidebottom      11751   CW       SK    GF     14      5
# 8136           Dane Swan       1460   CW       SK    GF     13      2
# 8137         Dale Thomas       4152   CW       SK    GF     17      8
# 8138         Alan Toovey      11553   CW       SK    GF      7      1
# 8139  Sharrod Wellingham      11654   CW       SK    GF     10      3
# 8140        Steven Baker        967   SK       CW   GF2      5      3
# 8141         Jason Blake        974   SK       CW   GF2     11      8
# 8142      Nick Dal Santo       1132   SK       CW   GF2     21      5
# 8143          Zac Dawson       4141   SK       CW   GF2      0      2
# 8144       Sean Dempster       4073   SK       CW   GF2      4      4
# 8145         Robert Eddy      11681   SK       CW   GF2      4      3
# 8146          Sam Fisher       3975   SK       CW   GF2     11      7
# 8147         Sam Gilbert       4178   SK       CW   GF2     11      6
# 8148     Brendon Goddard       1443   SK       CW   GF2     11      4
# 8149          Jason Gram       1462   SK       CW   GF2      7      3
# 8150         James Gwilt       4143   SK       CW   GF2     17      7
# 8151         Lenny Hayes        966   SK       CW   GF2     10      3
# 8152       Clinton Jones      11554   SK       CW   GF2      8      0
# 8153   Justin Koschitzke        977   SK       CW   GF2      6      2
# 8154          Ben McEvoy      11682   SK       CW   GF2      0      4
# 8155    Andrew McQualter       4104   SK       CW   GF2      4      3
# 8156       Stephen Milne        978   SK       CW   GF2      3      2
# 8172                1               2        0             1             78
# 8173                1               2        3             0            100
# 8174                1               0        0             0             83
# 8175                0               5        0             0             98
# 8176                0               0        0             1             80
# 8177                0               3        0             0             81
# 8178                0               6        5             1             97
# 8179                2               2        0             1             80
# 8180                0               2        1             0             90
# 8181                1               3        2             0             80
# 8182                1               1        0             0            100
# 8183                1               2        0             1             70
#
#       year
# 8096  2010
# 8097  2010
# 8098  2010
# 8099  2010
# 8100  2010
# 8101  2010
# 8102  2010
# 8103  2010
# 8104  2010
# 8105  2010
# 8106  2010
# 8107  2010
# 8108  2010
# 8109  2010
# 8110  2010
# 8111  2010
# 8112  2010
# 8113  2010
# 8114  2010
# 8115  2010
# 8116  2010
# 8117  2010
# 8118  2010
# 8119  2010
# 8120  2010
# 8121  2010
# 8122  2010
# 8123  2010
# 8124  2010
# 8125  2010
# 8126  2010
# 8127  2010
# 8128  2010
# 8129  2010
# 8130  2010
# 8131  2010
# 8132  2010
# 8133  2010
# 8134  2010
# 8135  2010
# 8136  2010
# 8137  2010
# 8138  2010
# 8139  2010
# 8140  2010
# 8141  2010
# 8142  2010
# 8143  2010
# 8144  2010
# 8145  2010
# 8146  2010
# 8147  2010
# 8148  2010
# 8149  2010
# 8150  2010
# 8151  2010
# 8152  2010
# 8153  2010
# 8154  2010
# 8155  2010
# 8156  2010
# 8157  2010
# 8158  2010
# 8159  2010
# 8160  2010
# 8161  2010
# 8162  2010
# 8163  2010
# 8164  2010
# 8165  2010
# 8166  2010
# 8167  2010
# 8168  2010
# 8169  2010
# 8170  2010
# 8171  2010
# 8172  2010
# 8173  2010
# 8174  2010
# 8175  2010
# 8176  2010
# 8177  2010
# 8178  2010
# 8179  2010
# 8180  2010
# 8181  2010
# 8182  2010
# 8183  2010

# %% [markdown]
# ### Now insert data into database.

# %%
import sqlite3

# Create afl database
conn = sqlite3.connect('afl.db')
c = conn.cursor()

PLAYER_STATS_TABLE = """
CREATE TABLE player_stats (
    round INT,
    year INT,
    player_id INT,
    player_name VARCHAR(255),
    team VARCHAR(50),
    opponent VARCHAR(50),
    kicks INT,
    marks INT,
    hand_balls INT,
    disp INT,
    goals INT,
    behinds INT,
    hit_outs INT,
    tackles INT,
    rebounds INT,
    inside_50 INT,
    clearances INT,
    clangers INT,
    frees_for INT,
    frees_against INT,
    brownlow INT,
    contested_possessions INT,
    uncontested_possessions INT,
    contested_marks INT,
    marks_inside_50 INT,
    one_percenters INT,
    bounces INT,
    goal_assists INT,
    percent_time_played INT,
    PRIMARY KEY (round, year, player_id)
);
"""

c.execute(PLAYER_STATS_TABLE)

# %%
def format_dataframe(df, year):
    # Rename columns to match the database schema
    # Assuming your DataFrame has columns named similarly to your database schema
    # Update this dictionary with the correct mappings
    column_mappings = {
        'player': 'player_name',
        'player_id': 'player_id',
        '%_time_played': 'percent_time_played',
        # Add other columns as necessary
    }
    df = df.rename(columns=column_mappings)

    # Convert data types if necessary
    # For example: df['goals'] = df['goals'].astype(int)

    # Add the 'year' column
    df['year'] = year

    return df

# %%
# Iterate over each DataFrame and insert into the database
for filename, df in data.items():
    year = filename[0:4]
    print('Inserting data for year: ' + year)

    # Add the 'year' column to the DataFrame
    formatted_df = format_dataframe(df, year)

    # Insert into afl.db using sqlite3
    formatted_df.to_sql('player_stats', conn, if_exists='append', index=False)

print("Data insertion complete.")
# Out:
# Inserting data for year: 1996
# Inserting data for year: 1997
# Inserting data for year: 1998
# Inserting data for year: 1999
# Inserting data for year: 2000
# Inserting data for year: 2001
# Inserting data for year: 2002
# Inserting data for year: 2003
# Inserting data for year: 2004
# Inserting data for year: 2005
# Inserting data for year: 2006
# Inserting data for year: 2007
# Inserting data for year: 2008
# Inserting data for year: 2009
# Inserting data for year: 2010
# Inserting data for year: 2011
# Inserting data for year: 2012
# Inserting data for year: 2013
# Inserting data for year: 2014
# Inserting data for year: 2015
# Inserting data for year: 2016
# Inserting data for year: 2017
# Inserting data for year: 2018
# Inserting data for year: 2019
# Inserting data for year: 2020
# Inserting data for year: 2021
# Inserting data for year: 2022
# Inserting data for year: 2023
# Data insertion complete.

# %%
# test query to see if data is in the database
c.execute("SELECT * FROM player_stats LIMIT 5;")
results = c.fetchall()

# %% [markdown]
# ### Below is OLD, for AWS RDS

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# PostgreSQL connection information
username = 'AFLadmin'
password = 'tQpwdxkTbxdnDzCh73Qr'
host = 'afldatabase.cahwanquwzda.ap-southeast-2.rds.amazonaws.com'
port = '5432'
database = 'afldatabase'

# Create a database connection using psycopg2
conn = psycopg2.connect(
    user=username,
    password=password,
    host=host,
    port=port,
    database=database
)

# Create a database engine
engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')

# %%
def format_dataframe(df, year):
    # Rename columns to match the database schema
    # Assuming your DataFrame has columns named similarly to your database schema
    # Update this dictionary with the correct mappings
    column_mappings = {
        'player': 'player_name',
        'player_id': 'player_id',
        '%_time_played': 'percent_time_played',
        # Add other columns as necessary
    }
    df = df.rename(columns=column_mappings)

    # Convert data types if necessary
    # For example: df['goals'] = df['goals'].astype(int)

    # Add the 'year' column
    df['year'] = year

    return df

# %%
# Remove all rows from the database table: player_stats
engine.execute('DELETE FROM player_stats')

# %%
# Iterate over each DataFrame and insert into the database
for filename, df in data.items():
    year = filename[0:4]
    print('Inserting data for year: ' + year)

    # Add the 'year' column to the DataFrame
    formatted_df = format_dataframe(df, year)

    # print(formatted_df.head(1))

    # Insert the data into the 'player_stats' table
    formatted_df.to_sql('player_stats', engine, if_exists='append', index=False)

print("Data insertion complete.")
# Out:
# Inserting data for year: 1996
# Inserting data for year: 1997
# Inserting data for year: 1998
# Inserting data for year: 1999
# Inserting data for year: 2000
# Inserting data for year: 2001
# Inserting data for year: 2002
# Inserting data for year: 2003
# Inserting data for year: 2004
# Inserting data for year: 2005
# Inserting data for year: 2006
# Inserting data for year: 2007
# Inserting data for year: 2008
# Inserting data for year: 2009
# Inserting data for year: 2010
# Inserting data for year: 2011
# Inserting data for year: 2012
# Inserting data for year: 2013
# Inserting data for year: 2014
# Inserting data for year: 2015
# Inserting data for year: 2016
# Inserting data for year: 2017
# Inserting data for year: 2018
# Inserting data for year: 2019
# Inserting data for year: 2020
# Inserting data for year: 2021
# Inserting data for year: 2022
# Inserting data for year: 2023
# Data insertion complete.
